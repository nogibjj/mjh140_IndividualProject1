# %% [markdown]
# ## Descriptive Statistics Using Pandas
# ---
# #### 0. Summary
#
# This notebook uses the pandas, seaborn, and matplotlib packages to perform a brief analysis of the Iris dataset. The notebook is divided into three sections:
#
# 1. Import Packages / Functions
# 2. Descriptive Statistics
# 3. Visualization
#
# ***
# #### 1. Import Packages / Functions
#
# The following functions will be imported from `/src/lib.py`
#
# - ``import_iris()`` : Import Iris dataset from csv file
# - ``describe_iris()`` : Returns descriptive statistics for Iris dataset
# - ``visualize_iris()`` : Generates plot of sepal length distribution for each species
#
# *NOTE: The warnings package is imported to suppress deprication warnings when generating visualizations. See Section 3: Visualization below.*

# %%
from lib import (import_iris, describe_iris, visualize_iris)
from matplotlib import pyplot as plt
import warnings

# %% [markdown]
# The Iris dataset is currently stored in the `/data` folder as a csv file. The dataset will be imported, cleaned for visualization, and stored in the **iris_data** variable as a pandas dataframe.

# %%
iris_data = import_iris("iris_data.csv")

# %% [markdown]
# ---
# #### 2. Descriptive Statistics
#
# The `describe_iris()` function uses the built-in pandas function, `pandas.describe()`, to return a pandas dataframe of descriptive statistics about the Iris dataset. The dataframe is printed as a table below.

# %%
summary = describe_iris(iris_data)
print(summary)
# Out:
#        PetalWidthCm  PetalLengthCm  SepalLengthCm  SepalWidthCm
# count        150.00         150.00         150.00        150.00
# mean           1.20           3.76           5.84          3.05
# std            0.76           1.76           0.83          0.43
# min            0.10           1.00           4.30          2.00
# 25%            0.30           1.60           5.10          2.80
# 50%            1.30           4.35           5.80          3.00
# 75%            1.80           5.10           6.40          3.30
# max            2.50           6.90           7.90          4.40

# %% [markdown]
# ---
# #### 3. Visualization
#
# The `visualize_iris()` function uses the Seaborn package to generate a boxplot visualization for the Iris dataset. The sepal length distribution for all three species is plotted below.
#
# *NOTE: Deprication warnings have been suppressed and have no bearing on the data presented.*

# %%
warnings.filterwarnings('ignore', category=FutureWarning)
plot = visualize_iris(iris_data)
plt.show()

# %% [markdown]
# ---
